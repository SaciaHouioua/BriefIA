# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pymysql
import sqlalchemy
from sqlalchemy import create_engine
engine= create_engine ('mysql+pymysql://root@localhost/carData')

# %%
car_data = pd.read_csv('carData.csv')
print(car_data)
car_data.to_sql('car', con=engine, if_exists='append')
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
# engine.execute("SELECT * FROM carData" ).fetchall()
pd.read_sql( )
# Out:
# [(0, 'ritz', 2014, 3.35, 5.59, 27000, 'Petrol', 'Dealer', 'Manual', 0),
#  (1, 'sx4', 2013, 4.75, 9.54, 43000, 'Diesel', 'Dealer', 'Manual', 0),
#  (2, 'ciaz', 2017, 7.25, 9.85, 6900, 'Petrol', 'Dealer', 'Manual', 0),
#  (3, 'wagon r', 2011, 2.85, 4.15, 5200, 'Petrol', 'Dealer', 'Manual', 0),
#  (4, 'swift', 2014, 4.6, 6.87, 42450, 'Diesel', 'Dealer', 'Manual', 0),
#  (5, 'vitara brezza', 2018, 9.25, 9.83, 2071, 'Diesel', 'Dealer', 'Manual', 0),
#  (6, 'ciaz', 2015, 6.75, 8.12, 18796, 'Petrol', 'Dealer', 'Manual', 0),
#  (7, 's cross', 2015, 6.5, 8.61, 33429, 'Diesel', 'Dealer', 'Manual', 0),
#  (8, 'ciaz', 2016, 8.75, 8.89, 20273, 'Diesel', 'Dealer', 'Manual', 0),
#  (9, 'ciaz', 2015, 7.45, 8.92, 42367, 'Diesel', 'Dealer', 'Manual', 0),
#  (10, 'alto 800', 2017, 2.85, 3.6, 2135, 'Petrol', 'Dealer', 'Manual', 0),
#  (11, 'ciaz', 2015, 6.85, 10.38, 51000, 'Diesel', 'Dealer', 'Manual', 0),
#  (12, 'ciaz', 2015, 7.5, 9.94, 15000, 'Petrol', 'Dealer', 'Automatic', 0),
# ...

# %% [markdown]
# pour commencer nous allons vérifier les dimensions de notre data set. On l'occurence, nous avons 301 lignes qui représentent les voitures et 9 colonnes qui premettent de les décrire (caractéristiques ou features)

# %%
car_data2 = pd.read_sql_table('carData', con=engine)
car_data2
# Out:
#      index Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0        0     ritz  2014           3.35           5.59       27000    Petrol
# 1        1      sx4  2013           4.75           9.54       43000    Diesel
# 2        2     ciaz  2017           7.25           9.85        6900    Petrol
# 3        3  wagon r  2011           2.85           4.15        5200    Petrol
# 4        4    swift  2014           4.60           6.87       42450    Diesel
# ..     ...      ...   ...            ...            ...         ...       ...
# 597    296     city  2016           9.50          11.60       33988    Diesel
# 598    297     brio  2015           4.00           5.90       60000    Petrol
# 599    298     city  2009           3.35          11.00       87934    Petrol
# 600    299     city  2017          11.50          12.50        9000    Diesel
# 601    300     brio  2016           5.30           5.90        5464    Petrol
#
# ...

# %%
car_data.shape

# %%
car_data.columns  # afficher les colonnes
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
car_data.head() # afficher l'entête pour voir la liste des colonnes
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
car_data #vérification que le data set s'est bien chargé
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
car_data.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type           int8
# Seller_Type         int8
# Transmission        int8
# Owner              int64
# dtype: object

# %%
car_data.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
car_data['Selling_Price'].value_counts()
# Out:
# 0.60     8
# 0.45     8
# 5.25     7
# 4.50     7
# 4.75     6
#         ..
# 19.99    1
# 4.35     1
# 0.80     1
# 0.27     1
# 7.20     1
# Name: Selling_Price, Length: 156, dtype: int64

# %%
car_data['Present_Price'].value_counts()
# Out:
# 9.40     15
# 13.60    13
# 5.70      8
# 4.43      7
# 1.47      7
#          ..
# 9.29      1
# 92.60     1
# 13.70     1
# 1.17      1
# 0.65      1
# Name: Present_Price, Length: 147, dtype: int64

# %%
car_data.describe() # les statiques rapides de base
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
car_data.groupby('Seller_Type').count() # il existe deux catégories : Dealer and individual
# Out:
#              Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# Seller_Type
# Dealer            195   195            195            195         195
# Individual        106   106            106            106         106
#
#              Fuel_Type  Transmission  Owner
# Seller_Type
# Dealer             195           195    195
# Individual         106           106    106

# %%
car_data['Seller_Type'] = car_data['Seller_Type'].astype('category').cat.codes 
# remplacer Dealer : 0 et individual : 1

# %%
car_data['Seller_Type'].hist()
# Out:
# <AxesSubplot:>

# %%
car_data.groupby('Transmission').count()
# Out:
#               Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# Transmission
# 0                   40    40             40             40          40
# 1                  261   261            261            261         261
#
#               Fuel_Type  Seller_Type  Owner
# Transmission
# 0                    40           40     40
# 1                   261          261    261

# %%
car_data['Transmission'] = car_data['Transmission'].astype('category').cat.codes
# remplacer Automatic : 0 et Manual : 1

# %%
car_data['Transmission'].hist()
# Out:
# <AxesSubplot:>

# %%
car_data.groupby('Fuel_Type').count().plot.bar()
# Out:
# <AxesSubplot:xlabel='Fuel_Type'>

# %%
car_data['Fuel_Type'] = car_data['Fuel_Type'].astype('category').cat.codes
# permet de remplacer Petrol : 0 , Diesel : 1, GPL : 3

# %%
car_data['Selling_Price'].hist()
# Out:
# <AxesSubplot:>

# %%
car_data['Year'].hist()
# Out:
# <AxesSubplot:>

# %%
car_data['Year'].hist()

# %%
car_data['Present_Price'].hist()
# Out:
# <AxesSubplot:>

# %%
car_data.groupby('Fuel_Type').count()
# Out:
#            Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# Fuel_Type
# 0                 2     2              2              2           2
# 1                60    60             60             60          60
# 2               239   239            239            239         239
#
#            Seller_Type  Transmission  Owner
# Fuel_Type
# 0                    2             2      2
# 1                   60            60     60
# 2                  239           239    239

# %%
# On remarque  deux outliers sur les grands prix
sns.catplot(x ='Fuel_Type', y ='Selling_Price', data = car_data)

# %%
# On remarque  deux outliers sur les grands prix
ax = sns.catplot(x='Year' , y= 'Selling_Price', data=car_data)
ax.set(xlim=(3, 16))

# %%
data = car_data[car_data["Selling_Price"] < 30]

# %%
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000          2
# 1        sx4  2013           4.75           9.54       43000          1
# 2       ciaz  2017           7.25           9.85        6900          2
# 3    wagon r  2011           2.85           4.15        5200          2
# 4      swift  2014           4.60           6.87       42450          1
# ..       ...   ...            ...            ...         ...        ...
# 296     city  2016           9.50          11.60       33988          1
# 297     brio  2015           4.00           5.90       60000          2
# 298     city  2009           3.35          11.00       87934          2
# 299     city  2017          11.50          12.50        9000          1
# 300     brio  2016           5.30           5.90        5464          2
#
#      Seller_Type  Transmission  Owner
# 0              0             1      0
# ...

# %%
# S'il y a quelques valeurs manquantes, on supprime ces lignes

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven   Fuel_Type  \
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    1.787375
# std       2.891554       5.082812       8.644115   38886.883882    0.425801
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    2.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    2.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    2.000000
# max    2018.000000      35.000000      92.600000  500000.000000    2.000000
#
#        Seller_Type  Transmission       Owner
# count   301.000000    301.000000  301.000000
# mean      0.352159      0.867110    0.043189
# std       0.478439      0.340021    0.247915
# min       0.000000      0.000000    0.000000
# 25%       0.000000      1.000000    0.000000
# ...

# %%
data.plot.scatter("Selling_Price", "Present_Price", c="Year", colormap='viridis',figsize=(12, 8))
# Out:
# <AxesSubplot:xlabel='Selling_Price', ylabel='Present_Price'>

# %%
sns.pairplot(car_data, diag_kind = 'kde', hue='Year’)
plt.text(-20, 25, ‘Toutes les paires numériques (+ en option catégorique)’, fontsize = 16,color=’r’)
# Out:
#   File "<ipython-input-35-4f8b7ec2297d>", line 1
#     sns.pairplot(car_data, diag_kind = 'kde', hue='Year’)
#                                                          ^
# SyntaxError: EOL while scanning string literal

# %%
sns.pairplot(car_data)

# %%
plt.figure(figsize=(7,5))
sns.heatmap(car_data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
car_data[car_data['Kms_Driven'] < 10000].groupby(['Year','Selling_Price']).mean()
# Out:
#                     Present_Price  Kms_Driven  Owner
# Year Selling_Price
# 2008 0.25                   0.580        1900      0
# 2011 0.50                   0.826        6000      0
#      1.05                   1.500        6900      0
#      2.85                   4.150        5200      0
# 2012 0.40                   0.830        5500      0
# 2013 1.05                   1.900        5400      0
#      3.50                   5.900        9800      0
# 2014 0.50                   0.880        8000      0
#      1.15                   2.400        7000      0
# 2015 0.40                   0.550        6700      0
#      0.65                   0.740        5000      0
#      5.50                   5.700        4492      0
# 2016 0.45                   0.545         750      0
#      0.72                   0.950         500      0
#      0.75                   0.800        7000      0
#      1.05                   1.215        5850      0
# ...

# %%
car_data[car_data["Selling_Price"] <30]["Year"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
car_data[car_data["Selling_Price"] <30].groupby(['Year','Kms_Driven']).mean().hist()
# Out:
# array([[<AxesSubplot:title={'center':'Selling_Price'}>,
#         <AxesSubplot:title={'center':'Present_Price'}>],
#        [<AxesSubplot:title={'center':'Owner'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# histogrammes des variables continues
for col in car_data.select_dtypes ('float'):
    plt.figure()
    sns.distplot(car_data[col])
# Out:
# /home/sacia/anaconda3/envs/MachineLearning/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/sacia/anaconda3/envs/MachineLearning/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# histogrammes des variables continues
for col in car_data.select_dtypes ('int64'):
    plt.figure()
    sns.distplot(car_data[col])
# Out:
# /home/sacia/anaconda3/envs/MachineLearning/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/sacia/anaconda3/envs/MachineLearning/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.relplot(data=car_data, x=car_data['Selling_Price'], y=car_data["Present_Price"], hue="Year")

# %%
sns.relplot(data=car_data, x='Selling_Price', y="Kms_Driven", hue="Year")

# %%
sns.relplot(data=car_data,x="Kms_Driven", y="Selling_Price",hue="Year")

# %%
 sns.relplot(data=car_data,x="Kms_Driven", y="Selling_Price",hue="Fuel_Type")

# %%
sns.relplot(data=car_data,x="Year", y="Selling_Price",hue="Fuel_Type")

# %%
sns.catplot(data=car_data, kind="strip", x="Car_Name", y="Selling_Price", hue="Year")

# %%
with sns.axes_style('white'):
    sns.jointplot("Year", "Selling_Price", data=car_data, kind='reg')
# Out:
# /home/sacia/anaconda3/envs/MachineLearning/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
g = sns.lmplot(x="Year", y="Selling_Prdata:image/png;base64,...", data=car_data)

# %% [markdown]
# Un modèle de regression linéaire et un modèle qui cherche à établir ou à trouver une relation entre une variable, dite expliquée "y", et une ou plusieurs variables, dites explicatives "x".
# Parmi les modèles de régression linéaire, le plus simple est cely=ui de l'ajustument affine qui consiste à déterminer la droite  " y = ax + b." approchant au mieux un nuage de points dans le plan.
